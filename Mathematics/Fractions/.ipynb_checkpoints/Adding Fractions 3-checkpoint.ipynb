# %% [markdown]
# <img src="images/Callysto_Notebook-Banner_Top_06.06.18.jpg">

# %%
# %%html
#
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
from nbvis.ggb import *

ggb = GGB()

# %% [markdown]
# # Adding Fractions Part 3 - Lowest Common Denominator
#
# ## Introduction
#
# Sometimes we will have to add two fractions where neither denominator is a multiple of the other.<br>
# A simple example of this is adding $\frac 1 2 + \frac 1 3$.<br>
# The number 3 is not a multiple of 2.<br>
# That means we cannot convert ''one half'' into some number of ''thirds''.<br>
# The number 2 is not a multiple of 3.<br>
# That means we cannot convert ''one third'' into some number of ''halves'' either.<br>
# So we cannot rewrite $\frac 1 2$ as something over 3
# and we cannot rewrite $\frac 1 3$ as something over 2.<br>
# (Actually, it is possible, but the numerator would not be a whole number!)<br>
# Instead, we have to convert both fractions!
#
# There are a couple of ways that we can do this.<br>
# We will learn both ways in this notebook.<br>
# Each way has its advantages and disadvantages.<br>
# The first way that we will learn in this notebook has very simple steps to follow.<br>
# However, it might require adding and multiplying big numbers.<br>
# The second way has more steps to follow, but might give smaller numbers to add and multiply.

# %% [markdown]
# ## Adding Fractions the Straightforward Way
#
# An easy way to add two fractions is this:
#
#  * Multiply the top and bottom of the first fraction by the denominator of the second fraction.
#  * Then multiply the top and bottom of the second fraction by the denominator of the first fraction.
#  * Now add.
#
# So to add $\frac 1 2 + \frac 1 3$, here is what to do:
#
# First, multiply the top and bottom of $\frac 1 2$ by 3 (the denominator of $\frac 1 3$).<br>
# Next, multiply the top and bottom of $\frac 1 3$ by 2, (the denominator of $\frac 1 2$).
#
# ![drawing3](images/drawing3.svg)
#
# After that, both fractions will have the same denominator: 6.<br>
#
#
# $$ \frac 1 2 + \frac 1 3
#     = \frac {1 \times 3} {2 \times 3} + \frac {1 \times 2} {3 \times 2}
#     = \frac 3 6 + \frac 2 6. $$
#
# Now add the fractions.
#
# $$ \frac 3 6 + \frac 2 6 = \frac 5 6. $$
#
# So $\frac 1 2 + \frac 1 3 = \frac 5 6$.
#
# It does not matter what the denominators of the two fractions are.<br>
# Because order of multiplication doesn't matter (for example, $2\times 3 = 3\times 2$), this will always work!

# %% [markdown]
# ## A Slightly Harder Example
#
# Here is a harder example.<br>
# Try adding $\frac 3 4 + \frac 5 6$.<br>
# Multiply the top and bottom of each fraction by the bottom of the other fraction.<br>
# First, multiply the top and bottom of $\frac 3 4$ by 6.<br>
# Next, multiply the top and bottom of $\frac 5 6$ by 4.<br>
# Then, we add.
#
# $$ \frac 3 4 + \frac 5 6
#     = \frac {3 \times 6} {4 \times 6} + \frac {5 \times 4} {6 \times 4}
#     = \frac {18} {24} + \frac {20} {24}
#     = \frac {38} {24}.$$
#
# There is something interesting about this example.<br>
# We converted quarters and sixths into twenty-fourths.<br>
# We actually could have converted to something easier: twelfths.<br>
# Instead of multiplying $\frac 3 4$ by $\frac 6 6$ and instead of multiplying $\frac 5 6$ by $\frac 4 4$,
# we could have done this instead:
#
# $$ \frac 3 4 + \frac 5 6
#     = \frac {3 \times 3} {4 \times 3} + \frac {5 \times 2} {6 \times 2}
#     = \frac {9} {12} + \frac {10} {12}
#     = \frac {19} {12}.$$
#
# The first method is straightforward and works no matter what denominators the fractions have.<br>
# However, we might end up with very large numerators and denominators.<br>
# A more extreme example is $\frac 1 {32} + \frac 1 {48}$.<br>
# Using the first method we would do this:
#
# $$ \frac 1 {32} + \frac 1 {48}
#     = \frac {1 \times 48} {32 \times 48} + \frac {1 \times 32} {48 \times 32}
#     = \frac {48} {1536} + \frac {32} {1536} = \frac {80} {1536}. $$
#
# We could have done this conversion instead though:
#
# $$ \frac 1 {32} + \frac 1 {48}
#     = \frac {1 \times 3} {32 \times 3} + \frac {1 \times 2} {48 \times 2}
#     = \frac {3} {96} + \frac {2} {96} = \frac {5} {96}. $$
#
# Both of these answers are correct, but notice how much smaller the numbers are in the second equation.<br>
# The second one is much easier to read.<br>
# For the rest of this notebook, we will see how to add fractions and keep the denominators small.

# %% [markdown]
# ## Lowest Common Multiple
#
# Here is a list of numbers.<br>
# The first row shows multiples of 4.<br>
# The second row gives multiples of 6.<br>
# These two lists have several numbers in common.
#
# ![](images/lcm.svg)
#
# $\DeclareMathOperator{\lcm}{lcm}$
# The multiples that two numbers have in common are called, of course, **common multiples**.<br>
# The smallest multiple that they have in common is called the **lowest common multiple**,
# or sometimes the **least common multiple**.<br><br>
# The lowest common multiple of two numbers is denoted by $\lcm(-,-)$.<br>
# So for example, the lowest common multiple of 4 and 6 is $\lcm(4,6)=12$.

# %% [markdown]
# ## Lowest Common Denominator
#
# Now let's look at a list of fractions equal to $\frac 3 4$ and a list of fractions equal to $\frac 5 6$
#
# ![](images/lcd.svg)
#
# Fractions with the same denominator have been matched together.<br>
# These matches show us the different conversions we can do to get $\frac 3 4$ and $\frac 5 6$ over a common denominator.<br>
# So we can convert them to $\frac 9 {12}$ and $\frac {10} {12}$.<br>
# Or we can convert them to $\frac {18} {24}$ and $\frac {20} {24}$.<br>
# If we made the lists even longer, we could find other choices.
#
# The match with the smallest denominator is the one where both denominators are 12.<br>
# So 12 is called the **lowest common denominator** of $\frac 3 4$ and $\frac 5 6$.<br>
# Remember that 12 was also the least common multiple of 4 and 6.<br>
# This is not a coincidence.<br>
# The lowest common denominator of two fractions is the same as the lowest common multiple of their denominators.

# %% [markdown]
# ## The Lowest Common Denominator Way
#
# Now that we have learned about lowest common denominators,
# we can learn the second way to add fractions.
#
# If we want to add two fractions with different denominators,
# first we have to convert them so that they have the same denominator.<br>
# If we want the top and bottom to be as small as possible after the conversion,
# we should look for the lowest common denominator.<br>
# So a second method for adding fractions is like this:
#
#  * Find the lowest common multiple of the two denominators.
#  * This is also the lowest common denominator of the fractions.
#  * Convert both fractions into fractions over their lowest common denominator.
#  * Add.
#
# Let's go back to the example of adding $\frac 3 4 + \frac 5 6$.<br>
# This time, let's follow the steps we just listed.
#
#  * The denominators of $\frac 3 4$ and $\frac 5 6$ are 4 and 6.
#    Their lowest common multiple is $\lcm(4,6) = 12$.
#  * So 12 is also the lowest common denominator of $\frac 3 4$ and $\frac 5 6$.
#  * Now we convert both fractions into twelfths.
#    We convert $\frac 3 4$ into $\frac 9 {12}$ and $\frac {10} {12}$.
#  * Finally, we add $\frac 9 {12} + \frac {10} {12} = \frac {19} {12}$.
#
# This is more work than the first method shown in this notebook.<br>
# To find the lowest common multiple of the two denominators,
# you have to write out a lot of multiples of both numbers and find the smallest multiple.<br>
# With time and practice, you might memorize the lowest common multiple for some small numbers,
# or learn some tricks to do it faster.

# %% [markdown]
# ## Visually
#
# Here is a way to visualize adding $\frac 3 4 + \frac 5 6$ using circles.<br>
# When you press **Convert**, the circles will represent $\frac {9} {12} + \frac {10} {12}$.<br>
# Press **Add** to add them.
#
# Notice how the first circle is cut into quarters.<br>
# When you press **Convert**, each of the quarters is cut into 3 smaller equal pieces.<br>
# That is what it looks like to multiply the top and bottom of $\frac 3 4$ by 3.
#
# The second circle is cut into sixths.<br>
# When you press **Convert**, each of those sixths are cut into 2 smaller equal pieces.<br>
# That is what it looks like to multiply the top and bottom of $\frac 5 6$ by 2.
#
# You can change the numerators and denominators if you want to add something else.

# %%
# %%html
#
# <div id="div_interactive_add">
#     <svg id="svg_interactive_add" width=960 height=260></svg>
# </div>
#
# <label>
#     Numerator 1:   <input id="numer1" type="range" value="3" min="0" max="20" step="1" onchange="update()"/><br>
#     Denominator 1: <input id="denom1" type="range" value="4" min="1" max="20"  step="1" onchange="update()"/><br>
#     Numerator 2:   <input id="numer2" type="range" value="5" min="0" max="20" step="1" onchange="update()"/><br>
#     Denominator 2: <input id="denom2" type="range" value="6" min="1" max="20"  step="1" onchange="update()"/><br>
#     <input id="button" type="button"/>
# </label>
#
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <script src="javascript/fractions.js"></script>
# <script src="javascript/lowest_common_denominator.js"></script>
#
# <script>
#
# var defaultNumer1, defaultDenom1, defaultNumer2, defaultDenom2;
#
# function update() {
#     defaultNumer1 = Number(d3.select("#numer1").property("value"));
#     defaultNumer2 = Number(d3.select("#numer2").property("value"));
#     defaultDenom1 = Number(d3.select("#denom1").property("value"));
#     defaultDenom2 = Number(d3.select("#denom2").property("value"));
#     reset();
# }
#
# update();
# reset();
#
# </script>

# %% [markdown]
# ## Practice
#
# Practice adding fractions with different denominators with this multiple choice game.

# %%
ggb.file("geogebra/fractions-game3.ggb") \
    .options(height = 400, \
            showAlgebraInput = False, \
            enableLabelDrags = False, \
            enableShiftDragZoom = False, \
            showResetIcon = True, \
            useBrowserForJS = False, \
            showToolBar = False, \
            showMenuBar = False) \
    .draw()

# %% [markdown]
# ## Conclusion
#
# In this notebook, we learned how to add fractions with different denominators.<br>
# We learned how to do it in two different ways.<br>
# Both ways work no matter what the denominators of the fractions are.<br>
# Now we are well equipped to add any fractions we come across!
#
# Or are we? There is still much much more about fractions to be learned.<br>
# In the wider world of math, the numerator and denominator of a fraction do not have to be whole numbers.<br>
# They can be decimal numbers like $\frac {0.4} {1.2}$.<br>
# They can even be fractions, like
#
# $$ \frac {\frac 1 2} {\frac 3 4}. $$
#
# They can be negative numbers, too.<br>
# Even if you have mastered adding fractions, there is still subtraction, multiplication, and division to learn.<br>
# So keep learning!

# %% [markdown]
# <img src="images/Callysto_Notebook-Banners_Bottom_06.06.18.jpg">
